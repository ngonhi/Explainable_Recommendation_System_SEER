# %%
# !git clone https://github.com/PreferredAI/seer.git
# Out:
# Cloning into 'seer'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 27 (delta 0), reused 27 (delta 0), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %%
ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
cd /content/drive/MyDrive/nlpdata/seer
# Out:
# /content/drive/MyDrive/nlpdata/seer

# %%
pip install -r requirements.txt

# %%
#!unzip /content/drive-download-20210203T095325Z-001.zip

# %%
# !python prepare_data.py --input /content/drive/MyDrive/nlpdata/camera/profile.csv --out data/camera --ratio_validation 0.2 --ratio_test 0.2
# Out:
# Input file: /content/drive/MyDrive/nlpdata/camera/profile.csv
# Split ratio: 0.6 0.2 0.2
# Output dir: data/camera
#
# Getting list of train/validation/test instances
# Filtering out unseen data in validation/test
# Exporting data for EFM/MTER training
# Done

# %%
pwd
# Out:
# '/content/seer'

# %%
# !python train_efm.py --indir data/camera --epoch 1000 --out data/camera/efm
# Out:
# FM model is only supported on Linux.
# Windows executable can be found at http://www.libfm.org.
# Input directory: data/camera
# Output directory: data/camera/efm
# # epoch: 1000
# alpha: 0.85
# # explicit factors: 40
# # latent factors: 60
# # most cared aspects: 15
# Seed value: None
#
#
# TEST:
# ...
#     |   RMSE |    AUC | NDCG@50 | Recall@10 | Recall@50 | Train (s) | Test (s)
# --- + ------ + ------ + ------- + --------- + --------- + --------- + --------
# EFM | 0.8776 | 0.5881 |  0.0146 |    0.0103 |    0.0528 |   37.2820 |   7.2750

# %%
# !python prepare_opinion_contextualization_data.py --indir data/camera --efm_dir data/camera/efm --out data/camera
# Out:
# Done export data to data/camera/test.csv
# Done export data to data/camera/validation.csv
# Done export data to data/camera/train.csv
# Grouping by sentence length: 100% 95/95 [00:00<00:00, 113.39it/s]

# %%
# !python train_asc2v.py --indir data/camera --gpu 0 --out data/camera/asc2v --context asc2v --epoch 20
# Out:
# /usr/local/lib/python3.7/dist-packages/chainer/_environment_check.py:73: UserWarning:
# --------------------------------------------------------------------------------
# CuPy (cupy-cuda101) version 7.4.0 may not be compatible with this version of Chainer.
# Please consider installing the supported version by running:
#   $ pip install 'cupy-cuda101>=6.3.0,<7.0.0'
#
# See the following page for more details:
#   https://docs-cupy.chainer.org/en/latest/install.html
# --------------------------------------------------------------------------------
#
#   requirement=requirement, help=help))
# GPU: 0
# # unit: 300
# # Minibatch-size: 32
# # epoch: 20
# Seed value: None
# Dropout: 0.0
# Trimfreq: 0
# NS power: 0.75
# Context: asc2v
# Input directory: data/camera
#
# Getting aspect-opinion pairs at data/camera/train.csv: 99525it [00:00, 138027.05it/s]
# Read data from data/camera/validation.csv into memory: 28516it [00:02, 9699.59it/s]
# ...

# %%
pwd
# Out:
# '/content/drive/My Drive/nlpdata/seer'

# %%
# !python seer.py --input A203Q1G7IMYOVY,B00004THCZ,lens,zoom --corpus_path ../../seer/data/camera/test.csv --strategy greedy-efm --preference_dir ../../seer/data/camera/efm --contextualizer_path ../../seer/data/camera/asc2v/model.params
# Out:
# /usr/local/lib/python3.7/dist-packages/chainer/_environment_check.py:73: UserWarning:
# --------------------------------------------------------------------------------
# CuPy (cupy-cuda101) version 7.4.0 may not be compatible with this version of Chainer.
# Please consider installing the supported version by running:
#   $ pip install 'cupy-cuda101>=6.3.0,<7.0.0'
#
# See the following page for more details:
#   https://docs-cupy.chainer.org/en/latest/install.html
# --------------------------------------------------------------------------------
#
#   requirement=requirement, help=help))
# User: A203Q1G7IMYOVY
# Item: B00004THCZ
# Demanded aspects: Counter({'lens': 1, 'zoom': 1})
# Simplify demanded aspects: {'lens': 1, 'zoom': 1}
# # Candidate sentences: 11
# --------------------
# Selected sentences   : ['i am looking for an even greater zoom now', 'this lens is fine']
# Generated explanation: ['i am looking for an even greater zoom now', 'this lens is great']
